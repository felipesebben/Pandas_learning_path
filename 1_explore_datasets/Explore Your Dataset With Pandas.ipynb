# %% [markdown]
# ## Loading the dataset

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import glob

# %%
CURRENT_DIR = Path.cwd()
DATA_DIR = CURRENT_DIR / "data"

# %%
print(pd.__version__)
# Out:
# 1.3.4

# %%
download_url = 'https://github.com/fivethirtyeight/data/blob/master/nba-elo/nbaallelo.csv'

# %% [markdown]
# Use `requests` package to hande HTTP tasks.

# %%
import requests

# %%
response = requests.get(download_url)

# %%
print(response.status_code)
# Out:
# 200

# %%
# !dir
# Out:
#  O volume na unidade C � OS
#  O N�mero de S�rie do Volume � D267-F612
#
#  Pasta de c:\Users\felip\python_work\pandas\1_explore_datasets
#
# 27/12/2021  10:29    <DIR>          .
# 27/12/2021  10:29    <DIR>          ..
# 27/12/2021  10:29           197.499 Explore Your Dataset With Pandas.ipynb
# 25/12/2021  16:10            37.316 exploring_dataframe_series_objects.ipynb
# 25/12/2021  16:35        18.173.265 nba_all_elo.csv
#                3 arquivo(s)     18.408.080 bytes
#                2 pasta(s)   1.765.391.171.584 bytes dispon�veis

# %%
nba = pd.read_csv(
    DATA_DIR / 'nba_all_elo.csv')

# %%
type(nba)
# Out:
# pandas.core.frame.DataFrame

# %%
len(nba)
# Out:
# 126314

# %%
nba.shape
# Out:
# (126314, 23)

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
pd.set_option('display.max.columns', None)
pd.set_option('display.precision',2)

# %%
nba.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %% [markdown]
# ## Getting to Know DataFrame Objects

# %% [markdown]
# Start off by calling the `.info()` method on the nba `DataFrame`. This reveals some interesting data about the dataset.

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# At the bottom, you can see that of the 23 columns, 6 are floats, 7 are integers, and 10 are objects. Also, none of the columns have null values except for `notes`.

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %% [markdown]
#  Let's make an exploratory analysis. Take a look at the number of games played by each team.

# %%
nba['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %% [markdown]
# The `.value_counts()` method will count the number of times each value occurs in a particular column, `team_id` in this example. So the team `BOS` played the most games with `5997`, and the team `SDS` played the fewest with `11`.

# %%
nba['fran_id'].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
nba['fran_id'] == 'Lakers'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309    False
# 126310    False
# 126311    False
# 126312    False
# 126313    False
# Name: fran_id, Length: 126314, dtype: bool

# %%
nba.loc[nba['fran_id'] == 'Lakers']
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1136          569  194811040BLB   NBA        1     1949   11/4/1948
# 1152          577  194811060WSC   NBA        1     1949   11/6/1948
# 1159          580  194811090BOS   NBA        1     1949   11/9/1948
# 1170          586  194811110NYK   NBA        1     1949  11/11/1948
# 1183          592  194811130PRO   NBA        1     1949  11/13/1948
# ...           ...           ...   ...      ...      ...         ...
# 126016      63009  201504080DEN   NBA        1     2015    4/8/2015
# 126052      63027  201504100LAL   NBA        0     2015   4/10/2015
# 126086      63044  201504120LAL   NBA        0     2015   4/12/2015
# 126115      63058  201504130SAC   NBA        1     2015   4/13/2015
# 126137      63069  201504150LAL   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 1136             1            0     MNL  Lakers   84  1527.00  1542.25
# ...

# %%
nba.loc[nba['fran_id'] == 'Lakers', 'team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
nba.loc[nba['team_id'] == 'MNL', 'date_game']
# Out:
# 1136     11/4/1948
# 1152     11/6/1948
# 1159     11/9/1948
# 1170    11/11/1948
# 1183    11/13/1948
#            ...
# 9701     3/19/1960
# 9702     3/20/1960
# 9709     3/22/1960
# 9711     3/24/1960
# 9715     3/26/1960
# Name: date_game, Length: 946, dtype: object

# %%
nba.loc[nba['team_id'] == 'MNL', 'date_game'].max()
# Out:
# '4/9/1959'

# %%
nba['date_played'] = pd.to_datetime(nba['date_game'])

# %%
nba.loc[nba['team_id'] == 'MNL', 'date_played'].max()
# Out:
# Timestamp('1960-03-26 00:00:00')

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
total_bos_points = nba.loc[nba['team_id'] == 'BOS', 'pts'].sum()

# %%
years_bos_played = len(nba.loc[nba['team_id'] == 'BOS', 'date_played'].apply(lambda v: v.year).unique())

# %%
total_bos_points / years_bos_played
# Out:
# 8949.771428571428

# %%
'points' in nba.axes[1]
# Out:
# False

# %%
'pts' in nba.axes[1]
# Out:
# True

# %%
'pts' in nba.keys()
# Out:
# True

# %%
nba.iloc[-2]
# Out:
# gameorder                      63157
# game_id                 201506170CLE
# lg_id                            NBA
# _iscopy                            0
# year_id                         2015
# date_game                  6/16/2015
# seasongame                       102
# is_playoffs                        1
# team_id                          CLE
# fran_id                    Cavaliers
# pts                               97
# elo_i                        1700.74
# elo_n                        1692.09
# win_equiv                      59.29
# opp_id                           GSW
# opp_fran                    Warriors
# opp_pts                          105
# opp_elo_i                    1813.63
# opp_elo_n                    1822.29
# game_location                      H
# game_result                        L
# forecast                        0.48
# notes                            NaN
# date_played      2015-06-16 00:00:00
# Name: 126312, dtype: object

# %%
nba.loc[5555:5559, ['fran_id', 'opp_fran', 'pts', 'opp_pts']]
# Out:
#       fran_id  opp_fran  pts  opp_pts
# 5555  Pistons  Warriors   83       56
# 5556  Celtics    Knicks   95       74
# 5557   Knicks   Celtics   74       95
# 5558    Kings    Sixers   81       86
# 5559   Sixers     Kings   86       81

# %%
current_decade = nba[nba['year_id'] > 2010]

# %%
current_decade.shape
# Out:
# (12658, 24)

# %%
nba['year_id'] > 2010
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309     True
# 126310     True
# 126311     True
# 126312     True
# 126313     True
# Name: year_id, Length: 126314, dtype: bool

# %%
nba[nba['year_id'] > 2010]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
nba['notes'].notnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309    False
# 126310    False
# 126311    False
# 126312    False
# 126313    False
# Name: notes, Length: 126314, dtype: bool

# %%
games_with_notes = nba[nba['notes'].notnull()]
games_with_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# ...

# %%
ers_teams = nba[nba['fran_id'].str.endswith('ers')]
ers_teams
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 7                1            0     PRO  Steamrollers   59  1300.00  1305.15
# ...

# %%
nba[(nba['team_id'] == 'BLB') & (nba['pts'] > 100) & (nba['opp_pts'] > 100)]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 1726            0     BLB  Baltimore  114  1421.94  1419.43      38.56    MNL
# 4890            0     BLB  Baltimore  126  1328.67  1356.65      25.80    BOS
# 4909            0     BLB  Baltimore  104  1349.83  1346.36      24.88    MNL
# 5208            0     BLB  Baltimore  107  1284.52  1282.24      19.58    NYK
# 5825            0     BLB  Baltimore  110  1303.75  1301.97      20.74    BOS
#
# ...

# %%
nba['pts'].sum()
# Out:
# 12976235

# %%
nba['fran_id'].unique()
# Out:
# array(['Huskies', 'Knicks', 'Stags', 'Falcons', 'Capitols', 'Celtics',
#        'Steamrollers', 'Ironmen', 'Bombers', 'Rebels', 'Warriors',
#        'Baltimore', 'Jets', 'Pistons', 'Lakers', 'Kings', 'Hawks',
#        'Denver', 'Olympians', 'Redskins', 'Waterloo', 'Packers', 'Sixers',
#        'Wizards', 'Bulls', 'Thunder', 'Squires', 'Stars', 'Rockets',
#        'Colonels', 'Pacers', 'Nuggets', 'Spurs', 'Spirits', 'Sounds',
#        'Floridians', 'Nets', 'Condors', 'Bucks', 'Suns', 'Clippers',
#        'Cavaliers', 'Trailblazers', 'Sails', 'Jazz', 'Mavericks',
#        'Pelicans', 'Heat', 'Timberwolves', 'Magic', 'Grizzlies',
#        'Raptors', 'Hornets'], dtype=object)

# %%
group_fran = nba.groupby('fran_id', sort=False)

# %% [markdown]
#  If you have a large `DataFrame` and the order is irrelevant, sorting can cause performance issues. Setting sort to `False` can prevent some of these problems.

# %%
group_fran

# %%
group_fran['pts'].sum()
# Out:
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# ...

# %%
year_results = nba[nba['fran_id'] == 'Bulls'].groupby(['year_id', 'game_result'])

# %%
year_results['game_id'].count()
# Out:
# year_id  game_result
# 1967     L              51
#          W              33
# 1968     L              57
#          W              30
# 1969     L              49
#                         ..
# 2013     W              50
# 2014     L              38
#          W              49
# 2015     L              38
#          W              56
# Name: game_id, Length: 98, dtype: int64

# %%
nba[
    (nba['fran_id'] == 'Warriors') &
    (nba['year_id'] == 2015)
].groupby(['is_playoffs', 'game_result'])['game_id'].count()
# Out:
# is_playoffs  game_result
# 0            L              15
#              W              67
# 1            L               5
#              W              16
# Name: game_id, dtype: int64

# %% [markdown]
# # Changing Columns in a DataFrame

# %% [markdown]
# Making a copy of the `DataFrame`:

# %%
nba_copy = nba.copy()

# %%
nba_copy['pts'] - nba_copy['opp_pts']
# Out:
# 0         -2
# 1          2
# 2         16
# 3        -16
# 4        -17
#           ..
# 126309   -21
# 126310    13
# 126311   -13
# 126312    -8
# 126313     8
# Length: 126314, dtype: int64

# %%
nba_copy['difference'] = nba_copy['pts'] - nba_copy['opp_pts']

# %%
nba_copy.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
nba_copy['difference'].max()
# Out:
# 68

# %%
nba_copy.rename(
    columns={
        'game_result': 'result',
        'game_location': 'location',
    },
    inplace=True
)

# %% [markdown]
# Adding `inplace = True` will modify the original `DataFrame` that `.rename()` was called on.

# %%
nba_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 25 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  object
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  elo_i        126314 non-null  float64
#  12  elo_n        126314 non-null  float64
#  13  win_equiv    126314 non-null  float64
#  14  opp_id       126314 non-null  object
#  15  opp_fran     126314 non-null  object
#  16  opp_pts      126314 non-null  int64
#  17  opp_elo_i    126314 non-null  float64
# ...

# %% [markdown]
# Dropping columns with `.drop()`. Remember that default axis is rows, so you'll want to define `axis=1` to drop columns.

# %%
elo_columns = ['elo_i', 'elo_n', 'opp_elo_i', 'opp_elo_n']
nba_copy.drop(elo_columns, axis=1)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %% [markdown]
# Have columns been removed? Not really, better use `inplace` argument and `info` in one step.

# %%
nba_copy.drop(elo_columns, axis=1, inplace=True)

# %%
nba_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 21 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  object
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  win_equiv    126314 non-null  float64
#  12  opp_id       126314 non-null  object
#  13  opp_fran     126314 non-null  object
#  14  opp_pts      126314 non-null  int64
#  15  location     126314 non-null  object
#  16  result       126314 non-null  object
#  17  forecast     126314 non-null  float64
# ...

# %% [markdown]
# # Specifying Data Types

# %% [markdown]
# When you imported the nba `DataFrame`, Pandas attempted to infer the data type for each column based on its values. Take a look at the column data types again.

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# You already saw an example of this earlier in the course with the `'date_game'` column. Right now, it’s an object,

# %%
nba['date_game']
# Out:
# 0         11/1/1946
# 1         11/1/1946
# 2         11/2/1946
# 3         11/2/1946
# 4         11/2/1946
#             ...
# 126309    6/11/2015
# 126310    6/14/2015
# 126311    6/14/2015
# 126312    6/16/2015
# 126313    6/16/2015
# Name: date_game, Length: 126314, dtype: object

# %% [markdown]
# Since dates can be represented in many ways, Pandas played it safe and instead of assuming that if it talks like a date and walks like a date, that it must be a date, used an object instead. However, Pandas provides the `.to_datetime()` function, which accepts a `Series`, or a `DataFrame` column, and converts the values to Python datetimes.

# %%
nba['date_game'] = pd.to_datetime(nba['date_game'])
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# You’ve seen that some columns only have a few distinct values—for example, the `'game_location'` column. Again, this column is of type object. However, the values represent categories or classes, as 'H' is home, 'A' is away, and 'N' is neutral. Thus, you can use the `Categorical` data type, which is specific to Pandas, to represent those values more efficiently.

# %%
nba['game_location'] = pd.Categorical(nba['game_location'])
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
#  This has two advantages. First, look at the memory usage of the nba DataFrame with the category data type. You’ll see that it is lower than the use of the object data type.
#  Pandas can make certain assumptions about the values now and can therefore optimize storage. Another potential benefit of categories is ranking them. Now, the nba dataset won’t use this because no one location is more important than the other, and you can see this by looking at the dtype attribute of the `'game_location'` column.

# %%
nba['game_location'].dtype
# Out:
# CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)

# %% [markdown]
# The `'game_result'` column stores if the game was a win or a loss, represented as either a 'W' or an 'L'. This could be stored as a category instead.

# %%
nba['game_result'].unique()
# Out:
# array(['L', 'W'], dtype=object)

# %%
nba['game_result'] = pd.Categorical(nba['game_result'])
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# # Cleaning Your Data

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# Most of the columns have 126,314 non-null values. And the DataFrame has 126,314 rows, thus those columns have no null or missing values. However, the `notes` column has only 5,424 non-null values, which says there are a lot of missing values in the `notes` column.

# %% [markdown]
# One way to manage missing data is to completely remove it. You can simply omit any row that has a column with missing values. The nba `DataFrame` only has missing values for the notes column, but the `.dropna()` method will search all columns in the `DataFrame` for nulls.

# %%
clean_nba = nba.dropna()
clean_nba.shape
# Out:
# (5424, 24)

# %% [markdown]
# For the nba `DataFrame`, the `notes` data is not that relevant, therefore it makes more sense to drop the column itself. There was a discussion about the axis keyword argument. The `.dropna()` method accepts the same argument and values. By default, it is `0`, which means *“Drop rows with missing values.”* However, if you explicitly set it to `1`, `.dropna()` will search for **columns** with missing values.

# %%
clean_nba = nba.dropna(axis=1)
clean_nba.shape
# Out:
# (126314, 23)

# %%
clean_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# And now you can see that `clean_nba` only has 23 columns. Also, the notes column has been removed.

# %% [markdown]
# If the notes column did have relevant information, you could keep it and replace just the missing values with a default value.

# %%
nba_copy = nba.copy()
nba_copy['notes'].fillna(
    value='no notes at all',
    inplace=True
)

# %% [markdown]
# The `.fillna()` method on a `Series` will take the value to insert.
#
# Also, you used the `inplace` argument to modify the calling `DataFrame` instead of returning the modified DataFrame. Look at `.info()` again.

# %%
nba_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# There are now 126,314 non-null values in the notes column. And if you `.describe()` the `notes` column, the value occurring the most is 'no notes at all'.

# %%
nba_copy['notes'].describe()
# Out:
# count              126314
# unique                232
# top       no notes at all
# freq               120890
# Name: notes, dtype: object

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %% [markdown]
# Look at the minimum value of the pts column.
#
# Apparently, there was at least one game in which a team scored no points. Did they even try? Let’s take a deeper look. If you look at the notes column, it says that this game was forfeited. Now since there’s only one game with 0 points it might not have much of an impact, but you can now proceed to either remove or handle this row.

# %%
nba[nba['pts'] == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 26684      13343  197210260VIR   ABA        1     1973 1972-10-26           7
#
#        is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 26684            0     DNR  Nuggets    0  1460.34  1457.45      40.41    VIR
#
#       opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 26684  Squires        2    1484.19    1487.08             A           L
#
#        forecast                           notes date_played
# 26684      0.33  at Richmond VA; forfeit to VIR  1972-10-26

# %% [markdown]
# Several times, you’ve seen the game_result column that records a win or loss for that game. But does every win match up with the rest of the data in the row?
#
# If a game result is a win, then the points scored for that row should be more than the opposition points scored. And for a loss, the opposition points should be greater.

# %% [markdown]
# You can test these conditions using a query.

# %%
nba[(nba['pts'] > nba['opp_pts']) & (nba['game_result'] != 'W')]
# Out:
# Empty DataFrame
# Columns: [gameorder, game_id, lg_id, _iscopy, year_id, date_game, seasongame, is_playoffs, team_id, fran_id, pts, elo_i, elo_n, win_equiv, opp_id, opp_fran, opp_pts, opp_elo_i, opp_elo_n, game_location, game_result, forecast, notes, date_played]
# Index: []

# %% [markdown]
# The first condition checks that the number of points scored by a team is greater than the number of opposition points. The second condition checks that the game was not a win. When joined with the AND operator (`&`), the query should yield no results. And it does, but there’s an easier way to see. Simply get the `.empty` attribute.

# %%
nba[(nba['pts'] > nba['opp_pts']) & (nba['game_result'] != 'W')].empty
# Out:
# True

# %% [markdown]
# Checking the opposite - reverse the first comparison and make sure the game was not a loss.

# %%
nba[(nba['pts'] < nba['opp_pts']) & (nba['game_result'] != 'L')].empty
# Out:
# True

# %% [markdown]
# ## Visualizing Your Pandas DataFrame

# %% [markdown]
# All data has a story to tell. So far, the language you’ve used to tell that story has been the values of the `DataFrame`, but there is another way. Visualizations summarize the values in the data and provide information to the clients.
#
# Charts and graphs can draw attention to points of interest and make the story obvious. Traditionally, visualizations in Python have been done with the `Matplotlib` package, and while it is very powerful and capable, the API has a learning curve. The Pandas API affords you the advantage of generating `Matplotlib` visualizations without the ceremony or noise.

# %% [markdown]
# Earlier in the course, you learned how to summarize data with `grouping` and `aggregation` methods. For example, here’s how to summarize the number of points scored each year by the New York Knicks.
#
# There were more than 50 years of data in the `DataFrame`. Can you see the highest or lowest scoring years? How about trends? It’s hard to do just by staring at the numbers and picking out the ones of interest.

# %%
knicks_pts_by_year = nba[nba['fran_id'] == 'Knicks'].groupby('year_id')['pts'].sum()

# %%
knicks_pts_by_year.plot()
# Out:
# <AxesSubplot:xlabel='year_id'>

# %% [markdown]
# You can generate a plot of the data just by calling the `.plot()` method on the Series. The default plot is a line plot. This chart clearly shows a peak around 1970 and a low point around 2000.

# %% [markdown]
# You can also create a bar chart simply by adding the keyword argument kind and setting it to 'bar'. T

# %%
knicks_pts_by_year.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_id'>

# %% [markdown]
# That’s a little cramped, so let’s just look at the past 10 years.

# %%
knicks_pts_by_year.tail(10).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year_id'>

# %% [markdown]
# And it’s obvious that 2012 was the lowest scoring year.

# %% [markdown]
# Another interesting visualization is the scatter plot that shows two values on different axes. This scatter plot shows the points versus opposition points for the Knicks after 2000.

# %%
nba[(nba['fran_id'] == 'Knicks') & (nba['year_id'] > 2000)].plot(kind='scatter', x='pts', y='opp_pts')
# Out:
# <AxesSubplot:xlabel='pts', ylabel='opp_pts'>

# %% [markdown]
# As you might expect, games in which the home team scored more points, the opposition scored more points as well. But there’s something hidden in this data. Set the size of the points using the `s` keyword argument.

# %%
nba[(nba['fran_id'] == 'Knicks') & (nba['year_id'] > 2000)].plot(kind='scatter', x='pts', y='opp_pts', s=0.5)
# Out:
# <AxesSubplot:xlabel='pts', ylabel='opp_pts'>

# %% [markdown]
# See the empty area along the diagonal? That represents games where the home and away teams scored the same number of points, or a tie. From the scatter plot, it seems that there were no tied games, but you can write a simple query just to make sure.

# %% [markdown]
# You can also create pie charts with Pandas. For example, how many games did the Miami Heat win versus lose in the year 2013? Here’s the query to get the data.

# %%
nba[nba['pts'] == nba['opp_pts']].empty
# Out:
# True

# %%
heat_13_wl = nba[
    (nba['fran_id'] == 'Heat') &
    (nba['year_id'] == 2013)
]['game_result'].value_counts()
heat_13_wl
# Out:
# W    82
# L    23
# Name: game_result, dtype: int64

# %% [markdown]
# This was a good year for the Heat, but how good? Use the pie chart to visualize the data.

# %%
heat_13_wl.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='game_result'>

# %% [markdown]
# They won more than 75% of the games.
